# %%
# !pip install -q transformers torch scipy pandas tqdm
# Out:
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Python313\python.exe -m pip install --upgrade pip
